# %% [markdown]
# 💻 Coding Exercise
# Task: Train and evaluate an SVM classifier on a dataset of your choice (use sklearn.datasets), compare performance with different kernels, and visualize decision boundaries for 2D data.
#
# Requirements:
# Load a dataset with at least 2 features (e.g., make_moons, make_circles, iris with 2 features).
# Train three SVM models — linear, polynomial, and RBF kernels.
# Compare accuracy scores on train and test sets.
# Plot decision boundaries for each kernel (use matplotlib).
#
# Restrictions:
# Do not use starter code from online sources.
# Write from scratch using sklearn and matplotlib.

# %%
from sklearn.datasets import make_moons
data=make_moons()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data[0],data[1],test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
model=SVC(kernel='linear')
model2=SVC(kernel='poly')
model3=SVC(kernel='rbf')

# %%
model.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred1=model.predict(X_test)
y_pred2=model2.predict(X_test)
y_pred3=model3.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
acc1=accuracy_score(y_test,y_pred1)
acc2=accuracy_score(y_test,y_pred2)
acc3=accuracy_score(y_test,y_pred3)
print(acc1,acc2,acc3)
# Out:
# 0.9 1.0 0.9

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
