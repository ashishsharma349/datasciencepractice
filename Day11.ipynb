# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'user_activity_dataset.csv')
# \u1234 = a way to write special Unicode characters directly in a string.
# Your file path accidentally triggered this because \u was read as "start of Unicode escape

# %%
df
# Out:
#      last_login_days  last_post  last_story  last_note  last_message  \
# 0                102        473          72        663           630
# 1                435        125         358        108           289
# 2                270        536         222         75           759
# 3                106        144         415        541           353
# 4                 71        524         552        313           638
# ..               ...        ...         ...        ...           ...
# 995              713        304         187         58           678
# 996               38        316          59        470           246
# 997              272        634         318        775           558
# 998              230          8         210        465           757
# 999               85        773         405         11           126
#
#      last_profile_searched  last_likes_given  last_comment_given  last_share  \
# ...

# %%
df.columns
# Out:
# Index(['last_login_days', 'last_post', 'last_story', 'last_note',
#        'last_message', 'last_profile_searched', 'last_likes_given',
#        'last_comment_given', 'last_share', 'post_count', 'followers_count',
#        'following_count', 'account_status'],
#       dtype='object')

# %%
df_copy=df[df.columns[:-1]][:2]
df_copy
# Out:
#    last_login_days  last_post  last_story  last_note  last_message  \
# 0              102        473          72        663           630
# 1              435        125         358        108           289
#
#    last_profile_searched  last_likes_given  last_comment_given  last_share  \
# 0                    146               196                 541         188
# 1                    117               732                 755         254
#
#    post_count  followers_count  following_count
# 0         429               64               29
# 1         579             9491             1257

# %%
df_copy.corr()
# Out:
#                        last_login_days  last_post  last_story  last_note  \
# last_login_days                    1.0       -1.0         1.0       -1.0
# last_post                         -1.0        1.0        -1.0        1.0
# last_story                         1.0       -1.0         1.0       -1.0
# last_note                         -1.0        1.0        -1.0        1.0
# last_message                      -1.0        1.0        -1.0        1.0
# last_profile_searched             -1.0        1.0        -1.0        1.0
# last_likes_given                   1.0       -1.0         1.0       -1.0
# last_comment_given                 1.0       -1.0         1.0       -1.0
# last_share                         1.0       -1.0         1.0       -1.0
# post_count                         1.0       -1.0         1.0       -1.0
# followers_count                    1.0       -1.0         1.0       -1.0
# following_count                    1.0       -1.0         1.0       -1.0
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(df_copy,annot=True)
# Out:
# <Axes: >

# %%
# fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 15))
# axes = axes.flatten()

# for i, col in enumerate(input_cols[:len(axes)]):  
#     axes[i].scatter(df_encoded[col], df_encoded[output_col])
#     axes[i].set_title(f'{col} vs {output_col}')
#     axes[i].set_xlabel(col)
#     axes[i].set_ylabel(output_col)

# plt.tight_layout()
# plt.show()
